# %% [markdown]
# <a href="https://colab.research.google.com/github/Nik852001/EDA-Capstone-Project/blob/main/EDA_Capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  AirBnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA Capstone Project
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  Nikhil Rajendra Mandavkar

# %% [markdown]
# ![Airbnb_Logo_Bélo.svg.png](data:image/png;base64,...)

# %% [markdown]
# ##**What is AirBnb?**

# %% [markdown]
# **Airbnb is an online marketplace that connects people who want to rent out their homes with people looking for accommodations in that locale. NYC is the most populous city in the United States, and one of the most popular tourism and business places globally. OR**
#
# **Airbnb, as in “Air Bed and Breakfast,” is a service that lets property owners rent out their spaces to travelers looking for a place to stay. Travelers can rent a space for multiple people to share, a shared space with private rooms, or the entire property for themselves.**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the AirBnb data analysis project, I will have the overview of the basic understanding of the dataset variables. What does the particular features means and how its distributed, what type of data is it. AirBnb dataset is having 16 columns in total. I can get this by basic inspection of our dataset. Some columns are not significant for our analysis which can also be kept off.
#
# Now let's look at some of the useful columns and understand the variables in our dataset.
#
# > **Unique columns**:
# 1.   id
# 2.   host_id
#
# > **Catagorical data columns**:
# 1.   name
# 2.   host_name
# 3.   neighbourhood
# 4.   neighbourhood_group
# 5.   room_type
#
# > **Date column**:
# 1.   last_review
#
# > **Numeric column**:
# 1.   latitude
# 2.   longitude
# 3.   price
# 4.   minimum_neight
# 5.   number_of_reviews
# 6.   reviews_per_month
# 7.   calculated_host_listing_count
# 8.   availability_365
#
#
# 1] **id**: It's a unique id for House/apartment.
#
# 2] **name**: Name of the listing House/Apartment.
#
# 3] host_id: host_id is the goverment approved id for each individuals who rent their properties on AirBnb.
#
# 4] **host_name**: host_name is basically the name of the individual or orginization who own a room/apartment on AirBnb website.
#
# 5] **neighbourhood_groups**: neighbourhood_groups are the cluster of neighbourhood in the area.
#
# 6] **room_type**: AirBnb has 3 categories for types of spaces
#  1]Entire House/Apartment
#  2]Private room
#  3]Shared room
#
# 7] **price**: The total price of AirBnb reservation is based on the rate srt by the Host, plus fee or costs determined by either the Host or AirBnb.
#
# 8] **minimum_nights**: minimum neight is criteria for booking that guest have to pay for book that House/room or apartment.
#
# 9] **last_review**: Number of review of each host submitted by guest as a feedback.
#
# 10] **reviews_per_month**: Number of review host get per month.
#
# 11] **lattitude**: lattitude is the measurement of distance north or south of the equator.
#
# 12] **longitude**: longitude is the measurement east and west of the prime meridian.
#
# 13] **last_review**: Latest review submitted by guest as a feedback.
#
# 14] **calculated_host_listing_count**: amount of listing per host.
#
# 15] **availability_365**: It is an indicator of the total number of days the listing is available for during the year.
#
# On the basis of this data given in the dataset we can analysis the different queries.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Nik852001/EDA-Capstone-Project

# %% [markdown]
# ## <b>Problem Statement</b>

# %% [markdown]
# ## Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
#
# ## This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.
#
# ##The different problem for which I analysied the data are:
#
# 1.   **What are unique values for room and neighbourhood_group?**
# 2.   **Which are the top 10 apartment/houses in the list?**
# 3.   **Which are the top 10 private and shared room?**
# 4.   **What is average room rent for the locality?**
# 5.   **Which are the top 15 most expensive locality in Airbnb listing?**
# 6.   **Which are the least expensive neighbourhood according to Airbnb listing?**
# 7.   **In which city most number of and least number of locality listed?**
# 8.   **What is the review score for different location?**

# %% [markdown]
# ##<b>Define Your Business Objective?</b>

# %% [markdown]
# **By finding the solution for the above problems I will find out in which location I need to provide more services. By finding the expensive and least expensive location, I will compare both of them and find the problem that least expensive location are faces and after finding the problem I will focus on solving the problem at that location. I will also get the information about the customer review and after analyzing it I will determined in which location customer faces the more problem and after that I will try to provide more services at that location. This analysis help to increase the revenue of the company by solving the problem that customer faces during the stay in their hotel. This analysis also help the customer to choose the best location for their stay according to their budget. For any traveller, the most important thing is the price because this sets the budget of his/her trip. So in the analysis I will figure out what is the average price per night. I will check for different room type and based on neighbourhood group to figure out what is the average per night stay.**

# %% [markdown]
# **Importing Libraries**

# %%
#connecting google drive with google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Data loading into the the dataset**

# %%
#loading data into dataset
path = "/content/drive/MyDrive/Airbnb NYC 2019.csv"
dataset = pd.read_csv(path)
dataset.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# *Now I need to check how many rows and columns are present in the dataset. It is also necessary to check how many unique values are present for each column. For this I will also use the nunique.*

# %%
#for checking rows and columns and unique values
print('\nRows : ',dataset.shape[0])
print('\nColumns :', dataset.shape[1])
print('\nColumns:',dataset.columns.to_list())
print(' \nUnique:\n',dataset.nunique())
# Out:
# Rows :  48895
#
# Columns : 16
#
# Columns: ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
#
# Unique:
#  id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# ...

# %%
#to find how many null values are present in each column

dataset.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
dataset
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#since both 'name' and 'host_name' has very less missing values as compared to 47,905 listings and 11452 unique hosts!
#we can fill these missing values in both with unknown & no_name respectively!

dataset['name'].fillna('unknown',inplace=True)
dataset['host_name'].fillna('no_name',inplace=True)

# %%
 #looks the null values are removed!
dataset[['host_name','name']].isnull().values.any()
# Out:
# False

# %% [markdown]
# For Nan Values in column reviews_per_month,replacing Nan with 0

# %%
dataset
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#replacing NaN with 0
dataset.fillna({'reviews_per_month' : 0}, inplace=True)

# %%
dataset
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# Also the column 'last_review' has many null values. And since it's not much required for our analysis as compared to number_of_reviews & reviews_per_month. We're good to drop this column.

# %%
#drop the last_review column from the dataset
dataset= dataset.drop(['last_review'],axis=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
#looking for there's no duplicate data present!
duplicate_data = dataset.duplicated()
print(duplicate_data.sum())
dataset[duplicate_data]
# Out:
# 0
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# **Let's check the most no of listings in the dataset!**

# %%
#top 5 listings on Airbnb in entire dataset:

listings_count_df=dataset['name'].value_counts()[:5].reset_index()
listings_count_df.rename(columns={'index':'Listings on Airbnb','name':'Total_listings'},inplace=True)
listings_count_df
# Out:
#              Listings on Airbnb  Total_listings
# 0                Hillside Hotel              18
# 1           Home away from home              17
# 2                       unknown              16
# 3  New york Multi-unit building              16
# 4            Brooklyn Apartment              12

# %% [markdown]
# *   Hillside Hotel is found to have listed more listings in entire dataset.

# %%
#top 10 hosts on the basis of no of listings in entire dataset!

top_10_hosts=dataset['host_name'].value_counts()[:10]

# %%
#printing the top_10_hosts
top_10_hosts
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
# Blueground      232
# Sarah           227
# Daniel          226
# Jessica         205
# Maria           204
# Name: host_name, dtype: int64

# %%
#visualising the bar graph of top 10host on the basis of no. of listing
top_10_hosts.plot(kind='bar',color='r')
plt.xlabel('top10_hosts')
plt.ylabel('total_listings')
plt.title('top 10 hosts on the basis of no of listings in entire NYC!')
# Out:
# Text(0.5, 1.0, 'top 10 hosts on the basis of no of listings in entire NYC!')

# %% [markdown]
# **Unique Values**
#
# It is very important to understand and analyze the Unique values because this will gives a lot of insight to the data and the user preference for a particular choice. We will take Room Type and Neighbourhood group

# %%
#printing the unique values from the room_type and neighbourhood_group columns..
print('Unique values for the room types are : ', dataset.room_type.unique())
print('Unique values for the neighbourhood group are : ', dataset.neighbourhood_group.unique())
# Out:
# Unique values for the room types are :  ['Private room' 'Entire home/apt' 'Shared room']
# Unique values for the neighbourhood group are :  ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']

# %% [markdown]
# *   From the above, we have 3 types of room in the dataset and 5 different types of neighbourhood group in the dataset are available.

# %% [markdown]
# **Room Types and Neighbourhood Group**
#
# I will check the distribution of room type by grouping the data.

# %%
#distribution of room type according to their types
dataset['room_type'].value_counts().plot(kind='bar',color=['r','b','y'])
plt.show()

# %% [markdown]
# *   From the above its clear that the Apartment and Private room data is more than that of shared rooms. In general, Shared rooms costs less and can be very useful for travellers who moves from one city to another city quite frequently.

# %% [markdown]
# **Room_types vs price on different neighbourhood groups**

# %%
#room_type vs price
g = sns.catplot(x="room_type", y="price", col="neighbourhood_group",
                data=dataset, saturation=.8,
                kind="bar",ci=None,  aspect=.9)
(g.set_axis_labels("", "Price ranges on room_types")
  .set_xticklabels(["Private room", "Entire home/apt", "Shared room"],rotation=90)
  .set(ylim=(0, 400))
  .despine(left=True))

# %% [markdown]
# *   Looks like a property/listing with Entire home/apt as room_type wins the show at NYC followed by private rooms.
# *  Manhattan has the highest price for room types with Entire home/apt ranging to nearly 240 USD/night, followed by Private room with 120 USD/night. And it's obvious being the most expensive place to live in!

# %% [markdown]
# **Room_types and their relation with availability in different neighbourhood groups**

# %%
#visualisation of room_type and their relation with availability
f,ax = plt.subplots(figsize=(15,8))
ax=sns.boxplot(x='neighbourhood_group',y='availability_365',data=dataset, palette="bright")
plt.title("Neighbourhood Group vs. Room Availabilty")
plt.xlabel('Neighbourhood groups')
plt.ylabel('Availability(365)')
plt.show()

# %% [markdown]
# *  Looking at the above categorical box plot we can identify that the listings in Staten Island seems to be more available throughout the year to more than 300 days. On an average, these listings are available to around 210 days every year followed by Bronx where every listings are available for 150 on an average every year.

# %% [markdown]
# **Let us see the distribution of type of room across NYC**

# %%
#trying to find where the coordinates belong from the latitude and longitude
sns.set(rc={"figure.figsize": (10, 8)})
ax= sns.scatterplot(data=dataset, x="longitude", y="latitude",hue='neighbourhood_group',palette='bright')
ax.set_title('Location Co-ordinates')
# Out:
# Text(0.5, 1.0, 'Location Co-ordinates')

# %%
#trying to find out the the distribution of the type of room across NYC using scatterplot
sns.set(rc={"figure.figsize": (10, 8)})
ax= sns.scatterplot(x=dataset.longitude, y=dataset.latitude,hue=dataset.room_type,palette='muted')
ax.set_title('Distribution of type of rooms across NYC')
# Out:
# Text(0.5, 1.0, 'Distribution of type of rooms across NYC')

# %% [markdown]
# * By the two scatterplots of latitude vs longitude we can identify there's is very less shared room throughout NYC as compared to private and Entire home/apt.
# * 95% of the listings on Airbnb are either Private room or Entire/home apt. Very few guests had opted for shared rooms on Airbnb.
# * Also, guests mostly prefer this room types when they are looking for a rent on Airbnb as we found out previously in our analysis.

# %% [markdown]
# **Top 10 neighbourhoods on the basis of no of listings in entire NYC!**

# %%
#top 10 neighbourhood 
top_10_neigbours= dataset['neighbourhood'].value_counts()[:10] 
top_10_neigbours.plot(kind='bar',color='r')
plt.xlabel('neighbourhood')
plt.ylabel('counts in entire NYC')
plt.title('Top neighbourhoods in entire NYC on the basis of count of listings')
# Out:
# Text(0.5, 1.0, 'Top neighbourhoods in entire NYC on the basis of count of listings')

# %% [markdown]
# **Top 10 apartment listing in the dataset**
#
# Below i am displaying the Entire Home/Apartment renting and it looks odd that Sonder(NYC) have itself is too high. We will also list out only the details for the user if they are genuine hotels or there is any discrepancy in the data.

# %%
#top 10 apartment listing in the dataset
apt = dataset[dataset['room_type']=='Entire home/apt']
list_apt = apt.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='apartment').sort_values(by=['apartment'],ascending=False)
list_apt.head(10)
# Out:
#          host_id     host_name       neighbourhood neighbourhood_group  \
# 20219  219517861  Sonder (NYC)  Financial District           Manhattan
# 6452     7503643          Vida          Greenpoint            Brooklyn
# 8434    12243051        Sonder  Financial District           Manhattan
# 20222  219517861  Sonder (NYC)         Murray Hill           Manhattan
# 17840  120762452       Stanley         Murray Hill           Manhattan
# 19908  205031545    Red Awning             Midtown           Manhattan
# 12278   30283594          Kara      Hell's Kitchen           Manhattan
# 17458  107434423    Blueground             Chelsea           Manhattan
# 17635  113805886        Yaacov     Upper East Side           Manhattan
# 12280   30283594          Kara             Midtown           Manhattan
#
#        apartment
# 20219        210
# 6452          52
# 8434          51
# 20222         50
# 17840         49
# 19908         49
# 12278         41
# 17458         37
# 17635         33
# ...

# %% [markdown]
# **Top 10 private room**

# %%
#top 10 private room in the listing
private = dataset[dataset['room_type']=='Private room']
list_private = private.groupby(['host_id','host_name','neighbourhood']).size().reset_index(name='private').sort_values(by=['private'],ascending=False)
list_private.head(10)
# Out:
#          host_id host_name       neighbourhood  private
# 15270  190921808      John      Hell's Kitchen       44
# 14032  137358866    Kazuya            Woodside       35
# 16311  238321374      Eyal     Upper West Side       32
# 15993  224414117   Gabriel      Hell's Kitchen       30
# 16044  226410657      Nina  Bedford-Stuyvesant       26
# 16154  230192510      Zach         Fort Greene       25
# 16396  242962235     Yuval           Ridgewood       23
# 16549  252604696      Erin             Chelsea       20
# 14668  159091490   Melissa             Gowanus       17
# 14031  137358866    Kazuya           Sunnyside       17

# %% [markdown]
# **Top 10 Shared room**

# %%
#top 10 shared room in the listing
shared = dataset[dataset['room_type']=='Shared room']
list_shared = shared.groupby(['host_id','host_name','neighbourhood']).size().reset_index(name='shared').sort_values(by=['shared'],ascending=False)
list_shared.head(10)
# Out:
#        host_id   host_name       neighbourhood  shared
# 339   39528519         Max     Lower East Side      23
# 529  119669058     Melissa  Bedford-Stuyvesant      18
# 651  201015598      Anchor  Bedford-Stuyvesant      17
# 618  175730239   Baboucarr           Sunnyside      10
# 663  209386156     Abraham         East Harlem       9
# 727  253906467        Erik      Hell's Kitchen       9
# 686  223087887  Jess & Ana              Corona       8
# 714  248161322      Sergii            Bushwick       8
# 292   30509656        Orit         Port Morris       8
# 635  187975743     R.Henry      Hell's Kitchen       8

# %% [markdown]
# **Let's look at the distribution of the listings with availability!**

# %%
#distribution of listings availability at NYC!
sns.distplot(dataset['availability_365'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# *  availability_365 have uniform distribution with availability ranging from 0 to 370

# %% [markdown]
# **Neighbourhood group**
#
# Lets see the data distribution of neighbourhood_group data.

# %%
#distribution of neighbourhood_group data
dataset['neighbourhood_group'].value_counts().plot(kind='bar',color=['r','b','y','g','m'])
plt.show()

# %%
#top 10 neighbourhood_group in listing
ng = dataset[dataset['neighbourhood_group']=='Manhattan']
list_ng = ng.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='count').sort_values(by=['count'],ascending=False)
list_ng.head(10)
# Out:
#          host_id     host_name       neighbourhood neighbourhood_group  count
# 15628  219517861  Sonder (NYC)  Financial District           Manhattan    218
# 5704    12243051        Sonder  Financial District           Manhattan     51
# 15631  219517861  Sonder (NYC)         Murray Hill           Manhattan     50
# 13773  120762452       Stanley         Murray Hill           Manhattan     50
# 15387  205031545    Red Awning             Midtown           Manhattan     49
# 15157  190921808          John      Hell's Kitchen           Manhattan     46
# 8895    30283594          Kara      Hell's Kitchen           Manhattan     41
# 13467  107434423    Blueground             Chelsea           Manhattan     37
# 13626  113805886        Yaacov     Upper East Side           Manhattan     33
# 8897    30283594          Kara             Midtown           Manhattan     33

# %% [markdown]
# *   From the above it looks like that the top 10 neighbourhood_group are from the Manhattan.

# %% [markdown]
# **Price Exploration**

# %%
#price exploration using describe()
dataset['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# *   According to the summary statistics it is clear that the Price ranges from  0−180. But there also exists price which has a maximum of $10000. This we cannot discard as an outlier because there are many scenarios in which price differs. The price varies on different factors which includes location,room type, neighbourhood , season etc.

# %% [markdown]
# **Average room rent for the locality**
#
# For any traveller, the most important thing is the price because this sets the budget of his/her trip. So in the below I will figure out what is the average price per night. I will check for different room type and based on neighbourhood group to figure out what is the average per night stay.

# %%
#average room rent for the locality
dataset.head()
plt.figure(figsize=(12,8))
df = dataset[dataset['minimum_nights']==1]
df1 = df.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True)
df1.plot(kind='bar')
plt.title('Average Price for rooms in neighbourhood group')
plt.ylabel('Average Daily Price')
plt.xlabel('Neighbourhood Group')
plt.show()
print('List of Average Price per night based on the neighbourhood group')
pd.DataFrame(df1).sort_values(by='room_type')
# Out:
# List of Average Price per night based on the neighbourhood group
#                                           price
# room_type       neighbourhood_group
# Entire home/apt Queens               139.036260
#                 Bronx                141.541176
#                 Brooklyn             202.895245
#                 Staten Island        266.205128
#                 Manhattan            291.784595
# Private room    Bronx                 69.025862
#                 Staten Island         71.394366
#                 Queens                72.454958
#                 Brooklyn              81.713284
#                 Manhattan            121.434183
# Shared room     Staten Island         21.000000
#                 Bronx                 46.711111
#                 Brooklyn              60.921212
#                 Queens                68.459459
#                 Manhattan             88.462898

# %% [markdown]
# *  **So looking at the plot it is observed that**:
#
# a. Shared room at staten Island is the most cheapest stay per night whereas renting a Entire apartment/Home at Manhattan per night is the most expensive.
#
# b. Average price for Private room is also considerably expensive at manhattan as well as the shared room at Manhattan is expensive than other private rooms of the neighbourhood. This clearly states that Manhattan is the expensive stay than any other locality.
#
# c. Bronx is the most cheapest stay in terms of neighbourhood group comparison in respect to room type.
#
# d. Though Shared room at Staten Island is the cheapest whereas Apartment renting is not cheapest at Staten Island.

# %% [markdown]
# **Now, Let's check the expensive & cheapest listings with respect to prices leading in entire NYC!**

# %%
#expensive listing with respect to price
dataset.sort_values(by='price', ascending=False)[['name','neighbourhood_group','neighbourhood','host_name','room_type']][:10]
# Out:
#                                                     name neighbourhood_group  \
# 9151                 Furnished room in Astoria apartment              Queens
# 17692    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 29238                                1-BR Lincoln Center           Manhattan
# 40433  2br - The Heart of NYC: Manhattans Lower East ...           Manhattan
# 12342                Quiet, Clean, Lit @ LES & Chinatown           Manhattan
# 6530                                  Spanish Harlem Apt           Manhattan
# 30268  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho           Manhattan
# 4377                                       Film Location            Brooklyn
# 29662          East 72nd Townhouse by (Hidden by Airbnb)           Manhattan
# 42523                70' Luxury MotorYacht on the Hudson           Manhattan
#
#            neighbourhood host_name        room_type
# 9151             Astoria  Kathrine     Private room
# ...

# %% [markdown]
# *  The most of the expensive listing belongs to the Manhattan.

# %%
#cheapest listing with respect to price
dataset.sort_values(by='price',ascending=True)[['name','neighbourhood_group','neighbourhood','host_name','room_type']][:10]
# Out:
#                                                     name neighbourhood_group  \
# 25796       Cozy yet spacious private brownstone bedroom            Brooklyn
# 25634    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)            Brooklyn
# 25433      ★Hostel Style Room | Ideal Traveling Buddies★               Bronx
# 25753                    Sunny, Quiet Room in Greenpoint            Brooklyn
# 23161  Huge Brooklyn Brownstone Living, Close to it all.            Brooklyn
# 25795  Contemporary bedroom in brownstone with nice view            Brooklyn
# 26841  Coliving in Brooklyn! Modern design / Shared room            Brooklyn
# 25778      Modern apartment in the heart of Williamsburg            Brooklyn
# 25794  Spacious comfortable master bedroom with nice ...            Brooklyn
# 26866             Best Coliving space ever! Shared room.            Brooklyn
#
#             neighbourhood     host_name        room_type
# 25796  Bedford-Stuyvesant       Adeyemi     Private room
# ...

# %% [markdown]
# *  Also, the cheapest listings mostly comes from Brooklyn, Bronx most of them are private rooms which makes sense.

# %% [markdown]
# **Expensive and Least Expensive Neighbourhood in AirBnb dataset**
#
# It is very much important in terms of price to understand which locality has the highest price margin in terms of night being spend by traveller.

# %%
# top 15 most expensive locality in AirBnb listing
print('Top 15 most expensive locality in Airbnb listing are :')
df4 = dataset.dropna(subset=["price"]).groupby("neighbourhood")[["neighbourhood", "price"]].agg("mean").sort_values(by="price",ascending=False).rename(index=str, columns={"price": "Average price per night based on neighbourhood"}).head(15)

df4.plot(kind='bar')
plt.show()
pd.DataFrame(df4)
# Out:
# Top 15 most expensive locality in Airbnb listing are :
#                    Average price per night based on neighbourhood
# neighbourhood
# Fort Wadsworth                                         800.000000
# Woodrow                                                700.000000
# Tribeca                                                490.638418
# Sea Gate                                               487.857143
# Riverdale                                              442.090909
# Prince's Bay                                           409.500000
# Battery Park City                                      367.557143
# Flatiron District                                      341.925000
# Randall Manor                                          336.000000
# NoHo                                                   295.717949
# SoHo                                                   287.103352
# Midtown                                                282.719094
# ...

# %%
# top 15 least expensive locality according to AirBnb listing
print('Least expensive neighbourhood according to Airbnb listing are')
df4 = dataset.dropna(subset=["price"]).groupby("neighbourhood")[["neighbourhood", "price"]].agg("mean").sort_values(by="price", ascending=False).rename(index=str, columns={"price": "Average price per night based on neighbourhood"}).tail(15)

df4.plot(kind='bar')
plt.show()
pd.DataFrame(df4)
# Out:
# Least expensive neighbourhood according to Airbnb listing are
#                 Average price per night based on neighbourhood
# neighbourhood
# Olinville                                            64.000000
# Borough Park                                         63.066176
# Castle Hill                                          63.000000
# Woodlawn                                             60.090909
# Corona                                               59.171875
# Mount Eden                                           58.500000
# Concord                                              58.192308
# Grant City                                           57.666667
# New Dorp Beach                                       57.400000
# Bronxdale                                            57.105263
# New Dorp                                             57.000000
# Soundview                                            53.466667
# Tremont                                              51.545455
# ...

# %% [markdown]
# *   So according to the above plot Fort Wadsworth is the most expensive in terms of neighbourhood, whereas Bull's head locality is the least expensive to stay.

# %% [markdown]
# **Top neighbourhoods in NYC with respect to average price/day of Airbnb listings:**

# %%
df_ngrp= dataset.groupby(['neighbourhood_group','neighbourhood'])['price'].mean().reset_index()

# %%
top_neigh= df_ngrp.loc[df_ngrp.groupby('neighbourhood_group')['price'].idxmax()].sort_values(by='price',ascending=False)
top_neigh
# Out:
#     neighbourhood_group   neighbourhood       price
# 188       Staten Island  Fort Wadsworth  800.000000
# 121           Manhattan         Tribeca  490.638418
# 88             Brooklyn        Sea Gate  487.857143
# 34                Bronx       Riverdale  442.090909
# 163              Queens        Neponsit  274.666667

# %% [markdown]
# *  Among the top neighbourhoods in each neighbourhood groups, top 2 of them namely: Fort Wadsworth & Tribeca, origins from Staten Island & Manhatten.
# Sea Gate from Brooklyn and Riverdale from Bronx and Neponsit from Queens.

# %%
top_neigh.plot.bar(x='neighbourhood', rot=90, title='Top Neighbourhoods in each neighbourhood groups in NYC')
plt.xlabel('neighbourhoods')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# **Most and Least number of locality listed**

# %%
df5 = dataset.groupby('neighbourhood')[['neighbourhood','host_name']].agg(['count'])['host_name'].sort_values(by='count',ascending=False).rename(index=str,columns={'Count':'Listing Count'})
df5.head(15).plot(kind='barh')
plt.show()
pd.DataFrame(df5.head(15))
# Out:
#                     count
# neighbourhood
# Williamsburg         3920
# Bedford-Stuyvesant   3714
# Harlem               2658
# Bushwick             2465
# Upper West Side      1971
# Hell's Kitchen       1958
# East Village         1853
# Upper East Side      1798
# Crown Heights        1564
# Midtown              1545
# East Harlem          1117
# Greenpoint           1115
# Chelsea              1113
# Lower East Side       911
# Astoria               900

# %%
print('Least Listing number of count')
df5 = dataset.groupby('neighbourhood')[['neighbourhood','host_name']].agg(['count'])['host_name'].sort_values(by='count',ascending=False).rename(index=str,columns={'Count':'Listing Count'})
df5.tail(15).plot(kind='barh')
plt.show()
pd.DataFrame(df5.tail(15))
# Out:
# Least Listing number of count
#                             count
# neighbourhood
# Huguenot                        3
# Breezy Point                    3
# Westerleigh                     2
# Howland Hook                    2
# Co-op City                      2
# Bay Terrace, Staten Island      2
# West Farms                      2
# Lighthouse Hill                 2
# Silver Lake                     2
# Rossville                       1
# Richmondtown                    1
# Willowbrook                     1
# Fort Wadsworth                  1
# New Dorp                        1
# Woodrow                         1

# %% [markdown]
# *   From the plot and the data we can see that the Williamsburg has most number of listing count where as Fort Wadesworth has one of the least listing i.e 1.

# %% [markdown]
# **On an average for how many nights people stayed in each room_types**

# %%
# min_night= dataset['room_type']
dataset.groupby('room_type')['minimum_nights'].mean().plot(kind='barh',color='r')
plt.title('Min Stays in different room types listed on Airbnb ')
plt.xlabel('Room types')
plt.ylabel('Min Stays')
# Out:
# Text(0, 0.5, 'Min Stays')

# %% [markdown]
# *  Looking at these it clearly indicates that people mostly prefer living in an entire home/apt on an average of more than 8 nights followed by guests who stayed in shared room where average stay is 6-7 nights.

# %% [markdown]
# **Lets look how monthly reviews varies with room types in each neighbourhood groups**

# %%
f,ax = plt.subplots(figsize=(10,8))
ax= sns.stripplot(x='room_type',y='reviews_per_month',hue='neighbourhood_group',dodge=True,data=dataset,palette='Set2')
ax.set_title('Most Reviewed room_types in each Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Most Reviewed room_types in each Neighbourhood Groups')

# %% [markdown]
# *   We can see that Private room recieved the most no of reviews/month where Manhattan had the highest reviews received for Private rooms with more than 50 reviews/month.
# *   Manhattan & Queens got the most no of reviews for Entire home/apt room type.
# *   There were less reviews recieved from shared rooms as compared to other room types and it was from Staten Island followed by Bronx.

# %% [markdown]
# **Location and the review score**
#
# Review is one of the important criteria to determined which location has got the good reviews. On the basis of reviews tourist can book the places.The criteria of our review is I will consider only those who have a review more than 50.

# %%
# location wise review score
fig = plt.figure(figsize=(12,4))
review_50 = dataset[dataset['number_of_reviews']>=50]
df2 = review_50['neighbourhood_group'].value_counts()
df2.plot(kind='bar',color=['r','b','g','y','m'])
plt.title('Location and Review Score(Min of 50)')
plt.ylabel('Number of Review')
plt.xlabel('Neighbourhood Group')
plt.show()
print(' Count of Review v/s neighbourhood group')
pd.DataFrame(df2)
# Out:
#  Count of Review v/s neighbourhood group
#                neighbourhood_group
# Brooklyn                      3065
# Manhattan                     2751
# Queens                         997
# Bronx                          187
# Staten Island                   81

# %% [markdown]
# *  So according to the above plot, Brooklyn got most review in comparison to Manhattan and Staten Island which is cheaper has less review than the other neighbourhood group.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Through this exploratory data analysis and visualization project, we gained several interesting insights into the Airbnb rental market. Below we will summarise the answers to the questions that we wished to answer at the beginning of the project:
#
#
# 1.   From the analysis we identify there are 3 type of rooms and 5 type of neighbourhood_group. We also see the distribution of room type and neighbourhood_group. After distribution we get the information that Entire home/apat and Private room data is more than that of the shared room and most of the neighbourhood_group are from the Manhattan. Most visitors don't prefer shared rooms, they tend to visit private room or entire home.
#
# 2.  From the analysis we get the information that Fort Wadsworth is the most expensive in terms of neighbourhood, whereas Bull's head locality is the least expensive to stay. From the analysis we also get information that Williamsburg has most number of listing count where as Fort Wadesworth has one of the least listing i.e 1. Fort Wadesworth has one of the least listing but it is most expensive in term of neighbourhood this is because of the location and the service provided at that loacation.
#
# 3.  Manhattan and Brooklyn has more number of listing than that of the Queens,Bronx and Staten island. Shared room at staten Island is the most cheapest stay per night whereas renting a entire apartment/Home at Manhattan per night is the most expensive. Average price for Private room is also considerably expensive at manhattan so as the shared room at Manhattan is expensive than other private rooms of the neighbourhood. This clearly states that Manhattan is the expensive stay than any other locality. Bronx is the most cheapest stay in terms of neighbourhood group comparison in respect to room type. Though Shared room at Staten Island is the cheapest whereas Apartment renting is not cheapest at Staten Island and this can be due to the location of a perfect gateway from the rush of the city for a quality time with family get together.
#
# 4. Understanding your customers is key to running a successful business. The customer reviews can provide a wealth of information if mined properly. After analyzing the customer review  Brooklyn got most review in comparison to Manhattan and Staten Island which is cheaper has less review than the other neighbourhood group.The places that got a good customer reviews is because of  positive themes that made people “comfortable” were cleanliness. A few themes weren’t pleasurable for the customer are room size (described by “small”,“stuffy”), temperature/heating issues (“cold”,“hot”,“damp”) and safety issues (“nervous”,“unsafe”,“stressful”) and becuse of that customer gives bad reviews. So after analyzing the data we will find out which places got the bad reviews. So at that places we need to resolve this problem and need to provide more services to the customers.
